# %%
push!(LOAD_PATH, "$(pwd())/../src"); using PyPlot, StatsBase, Distributions, StochasticProcesses;

# %% [markdown]
# # Stochastic Calculus Exercises

# %% [markdown]
# Generalized Ito process: $ dy = f(t, y, dt, dB) $

# %% [markdown]
# ## Ito Integral

# %% [markdown]
# `ItoIntegral(f)`:
#
# $$ y(t) = \int_{t_0}^{t} f(t) dB $$

# %% [markdown]
# $ \int_0^t t^2 dB $

# %%
for n in [10, 100, 1000]
    t=linspace(0., 10., n)
    plot(t, cumsim(ItoIntegral(x->x.^2), t))
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c4e1d8940>)

# %% [markdown]
# Ito integral converges:

# %%
let nn=[10, 100, 1000]
    fig, axis = subplots(1, length(nn), sharey=true)
    for (i, n) in enumerate(nn)
        t=linspace(0., 10., n)
        axis[i][:plot](t, cumsim(ItoIntegral(x->x.^2), t, 1000), color=(0, 0, 0, .01))
    end
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c3b593390>)

# %%
for n in [1000, 2000, 4000, 8000]
    t=linspace(0., 10., n)
    plt[:hist](sim(ItoIntegral(x->x.^2), t, 10000), alpha=0.2, bins=50, normed=true)
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c3ad68208>)

# %%
# todo: compare to analytical solution

# %% [markdown]
# ### More Ito Integral Examples

# %% [markdown]
# $ \int sin(t) dB $

# %%
t=linspace(0.,10,1000)
plot(t, cumsim(ItoIntegral(x->sin(x)), t, 1000), color=(0, 0, 0, .05));
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c3645c4e0>)

# %% [markdown]
# ## Stochastic Differential Equations

# %% [markdown]
# $ y(t) = \int_0^t f(t, y) dt + \int_0^t g(t, y) dB $ also written as $ dy = f(t, y) dt + g(t, y) dB $

# %% [markdown]
# ### SDE Examples

# %%
t=linspace(0.0, 1.0, 1000)
plot(t, cumsim(SDE((x, y)-> y .* (1+ sin(4 * pi * x)), (x, y)-> .1, 1.0), t, 1000), color=(0, 0, 0, .01));
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c36265f98>)

# %% [markdown]
# ## Ito Processes Properties

# %% [markdown]
# $dt dB = 0$

# %%
for n in [10, 100, 1000, 10000]
    t=linspace(0.,1.,n)
    plot(t, cumsim(ItoProcess((t,dt,b,db,y)->dt*db, .0), t))
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c356f38d0>)

# %%
for n in [1000, 2000, 4000, 8000]
    t=linspace(0., 1., n)
    plt[:hist](sim(ItoProcess((t,dt,b,db,y)->dt*db, 0.), t, 10000), alpha=0.2, bins=50, normed=true);
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c3ae11a90>)

# %%
t=linspace(0., 1., 1000)
plot(t, cumsim(ItoProcess((t,dt,b,db,y)->dt*db, 0.), t, 1000), color=(1, 0, 0, .01));
plot(t, cumsim(BrownianMotion(), t, 1000), color=(0, 0, 0, .01));
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c387d9320>)

# %% [markdown]
# $dB dB=t$

# %%
for (i, n) in enumerate([10, 100, 1000, 10000])
    t=linspace(0.,1,n)
    plot(t, cumsim(ItoProcess((t,dt,b,db,y)->db.^2, 0.), t))
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c356a8898>)

# %%
for n in [1000, 2000, 4000, 8000]
    t=linspace(0., 1., n)
    plt[:hist](sim(ItoProcess((t,dt,b,db,y)->db.^2, 0.), t, 10000), alpha=0.2, bins=50, normed=true);
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c37552f28>)

# %%
t=linspace(0., 1., 1000)
plot(t, cumsim(ItoProcess((t,dt,b,db,y)->db.^2, 0.), t, 1000), color=(0, 0, 0, .01));
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c37552da0>)

# %% [markdown]
# ## Ito's Lemma

# %% [markdown]
# Assume $ dy = f dt + g dB$, then if $F(t,y)$ is twice differentiable:
# $ dF(t, y) = \left(\frac{\partial F}{\partial t}+ f \frac{\partial F}{\partial y} + \frac{g^2}{2} \frac{\partial^2 F}{\partial y^2} \right) dt +  g \frac{\partial F}{\partial y}dB$

# %% [markdown]
# For ordinary integrals $d(t^2)=2t dt$:

# %%
let t0=0.0, t1=2.0, n=1000, t=linspace(t0,t1,n)
    plot(t, cumsim(CompositeProcess(ItoProcess((t,dt,b,db,y)->dt, 0.), (t, y)->y.^2), t))
    plot(t, cumsim(ItoProcess((t,dt,b,db,y)->2 * t * dt, 0.), t))
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c374769e8>)

# %% [markdown]
# For stochastic integrals $d(y^2) \neq 2ydB$ but $ d(y^2) = dt + 2 y dB$

# %%
fig, axis = subplots(1, 3, sharey=true)
let t0=0.0, t1=2.0, n=1000, t=linspace(t0,t1,n)
    axis[1][:set_ylim](-1, 50)
    axis[1][:plot](t, cumsim(CompositeProcess(ItoProcess((t,dt,b,db,y)->db, 0.), (t, y)->y.^2), t, 1000), color=(0,0,0,.01))
    axis[2][:plot](t, cumsim(ItoProcess((t,dt,b,db,y)->2*b.*db, 0.), t, 1000), color=(0,0,0,.01))
    axis[3][:plot](t, cumsim(ItoProcess((t,dt,b,db,y)->dt .+ 2*b.*db, 0.), t, 1000), color=(0,0,0,.01))
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c342b78d0>)

# %%
let t=linspace(0., 1., 10000)
    plt[:hist](sim(CompositeProcess(ItoProcess((t,dt,b,db,y)->db, 0.), (t, y)->y.^2), t, 10000), label="db^2", alpha=.5, bins=50, normed=true);
    plt[:hist](sim(ItoProcess((t,dt,b,db,y)-> 2 * b.*db, 0.), t, 10000),label="2bdb", alpha=.5, bins=50, normed=true);
    plt[:hist](sim(ItoProcess((t,dt,b,db,y)->dt .+ 2 * b.*db, 0.), t, 10000), label="dt+2bdb", alpha=.5, bins=50, normed=true);
    legend()
end;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3c36506278>)
